# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from keras.utils.np_utils import to_categorical
from sklearn.utils import class_weight
import warnings
import keras
from keras.layers import Dense, Convolution1D, MaxPool1D, Flatten, Dropout
from keras.layers import Input
from keras.models import Model
from keras.layers import BatchNormalization

from keras.callbacks import EarlyStopping, ModelCheckpoint
warnings.filterwarnings('ignore')

# %%
train_df=pd.read_csv('mitbih_train.csv',header=None)
test_df=pd.read_csv('mitbih_test.csv',header=None)

# %%
train_df[187]=train_df[187].astype(int)
equilibre=train_df[187].value_counts()
print(equilibre)
# Out:
# 0    72471
# 4     6431
# 2     5788
# 1     2223
# 3      641
# Name: 187, dtype: int64

# %%
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(equilibre, labels=['n','q','v','s','f'], colors=['red','green','blue','skyblue','orange'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
from sklearn.utils import resample
df_1=train_df[train_df[187]==1]
df_2=train_df[train_df[187]==2]
df_3=train_df[train_df[187]==3]
df_4=train_df[train_df[187]==4]
df_0=(train_df[train_df[187]==0]).sample(n=20000,random_state=42)

df_1_upsample=resample(df_1,replace=True,n_samples=20000,random_state=123)
df_2_upsample=resample(df_2,replace=True,n_samples=20000,random_state=124)
df_3_upsample=resample(df_3,replace=True,n_samples=20000,random_state=125)
df_4_upsample=resample(df_4,replace=True,n_samples=20000,random_state=126)

train_df=pd.concat([df_0,df_1_upsample,df_2_upsample,df_3_upsample,df_4_upsample])

# %%
equilibre=train_df[187].value_counts()
print(equilibre)

plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(equilibre, labels=['n','q','v','s','f'], colors=['red','green','blue','skyblue','orange'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 0    20000
# 1    20000
# 2    20000
# 3    20000
# 4    20000
# Name: 187, dtype: int64

# %%
c=train_df.groupby(187,group_keys=False).apply(lambda train_df : train_df.sample(1))
c
plt.plot(c.iloc[0,:186])

# %%
def plot_hist(class_number,size,min_,bins):
    img=train_df.loc[train_df[187]==class_number].values
    img=img[:,min_:size]
    img_flatten=img.flatten()

    final1=np.arange(min_,size)
    for i in range (img.shape[0]-1):
        tempo1=np.arange(min_,size)
        final1=np.concatenate((final1, tempo1), axis=None)
    print(len(final1))
    print(len(img_flatten))
    plt.hist2d(final1,img_flatten, bins=(bins,bins),cmap=plt.cm.jet)
    plt.show()

# %% [markdown]
# PRETREAT

# %%
def add_gaussian_noise(signal):
    noise=np.random.normal(0,0.5,186)
    return (signal+noise)

# %%
tempo=c.iloc[0,:186]
bruiter=add_gaussian_noise(tempo)

plt.subplot(2,1,1)
plt.plot(c.iloc[0,:186])

plt.subplot(2,1,2)
plt.plot(bruiter)

plt.show()

# %%
target_train=train_df[187]
target_test=test_df[187]
y_train=to_categorical(target_train)
y_test=to_categorical(target_test)

# %%
X_train=train_df.iloc[:,:186].values
X_test=test_df.iloc[:,:186].values
for i in range(len(X_train)):
    X_train[i,:186]= add_gaussian_noise(X_train[i,:186])
X_train = X_train.reshape(len(X_train), X_train.shape[1],1)
X_test = X_test.reshape(len(X_test), X_test.shape[1],1)

# %%
print(f"X_train samples: {X_train.shape[0]}")
print(f"y_train samples: {y_train.shape[0]}")
print(f"X_test samples: {X_test.shape[0]}")
print(f"y_test samples: {y_test.shape[0]}")

import numpy as np

# Suponiendo que y_train es tu arreglo o lista
unique_values, counts = np.unique(y_train, return_counts=True)

# Imprimir los valores únicos y sus conteos
for value, count in zip(unique_values, counts):
    print(f"Valor: {value}, Cantidad: {count}")
# Out:
# X_train samples: 100000
# y_train samples: 100000
# X_test samples: 21892
# y_test samples: 21892
# Valor: 0.0, Cantidad: 400000
# Valor: 1.0, Cantidad: 100000

# %% [markdown]
# Entrenamiento del modelo con las caracteristicas extraidas:

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from keras.utils.np_utils import to_categorical

# Cargar datos
# df_train = pd.read_csv('train_data.csv')
# df_test = pd.read_csv('test_data.csv')
df_train = pd.read_csv('train_data.csv')
df_test = pd.read_csv('test_data.csv')

# Preprocesar los datos
X_train = df_train.iloc[:, 2:].values
y_train = df_train.iloc[:, 1].values
X_test = df_test.iloc[:, 2:].values
y_test = df_test.iloc[:, 1].values

# Convertir etiquetas a numéricas
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Codificar las etiquetas
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Escalar las características
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Cambiar la forma de los datos para la red
X_train = X_train.reshape(len(X_train), X_train.shape[1], 1)
X_test = X_test.reshape(len(X_test), X_test.shape[1], 1)

# %%
print(f"X_train samples: {X_train.shape[0]}")
print(f"y_train samples: {y_train.shape[0]}")
print(f"X_test samples: {X_test.shape[0]}")
print(f"y_test samples: {y_test.shape[0]}")

#Por qué hay pocos datos y falta una clase?
# Out:
# X_train samples: 7200
# y_train samples: 7200
# X_test samples: 2402
# y_test samples: 2402

# %%
model, history = network(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 225/225 [==============================] - 2s 5ms/step - loss: 0.8687 - accuracy: 0.6500 - val_loss: 1.2307 - val_accuracy: 0.4654
# Epoch 2/40
# 225/225 [==============================] - 1s 3ms/step - loss: 0.7044 - accuracy: 0.7247 - val_loss: 1.5959 - val_accuracy: 0.3018
# Epoch 3/40
# 225/225 [==============================] - 1s 3ms/step - loss: 0.6410 - accuracy: 0.7531 - val_loss: 1.8529 - val_accuracy: 0.3518
# Epoch 4/40
# 225/225 [==============================] - 1s 4ms/step - loss: 0.6013 - accuracy: 0.7711 - val_loss: 2.2603 - val_accuracy: 0.3376
# Epoch 5/40
# 225/225 [==============================] - 1s 7ms/step - loss: 0.5808 - accuracy: 0.7836 - val_loss: 1.9482 - val_accuracy: 0.3659
# Epoch 6/40
# 225/225 [==============================] - 1s 5ms/step - loss: 0.5523 - accuracy: 0.7951 - val_loss: 1.9883 - val_accuracy: 0.3768
# Epoch 7/40
# 225/225 [==============================] - 1s 3ms/step - loss: 0.5348 - accuracy: 0.7997 - val_loss: 2.4571 - val_accuracy: 0.3310
# Epoch 8/40
# 225/225 [==============================] - 1s 3ms/step - loss: 0.5178 - accuracy: 0.8083 - val_loss: 3.2036 - val_accuracy: 0.2760
# Epoch 9/40
# 225/225 [==============================] - 1s 5ms/step - loss: 0.4964 - accuracy: 0.8161 - val_loss: 2.4135 - val_accuracy: 0.3693

# %%
evaluate_model(history,X_test,y_test,model)
# Out:
# Accuracy: 72.02%
# <keras.callbacks.History object at 0x000002240D183BB0>
# 76/76 [==============================] - 0s 1ms/step

# %%
def network(X_train, y_train, X_test, y_test):
    im_shape = (X_train.shape[1], 1)
    inputs_cnn = Input(shape=im_shape, name='inputs_cnn')

    # Capa Conv1D #1
    conv1_1 = Convolution1D(64, 3, activation='relu', input_shape=im_shape)(inputs_cnn)
    conv1_1 = BatchNormalization()(conv1_1)
    pool1 = MaxPool1D(pool_size=2, strides=2, padding="same")(conv1_1)

    # Capa Conv1D #2\n",
    conv2_1 = Convolution1D(64, 3, activation='relu')(pool1)
    conv2_1 = BatchNormalization()(conv2_1)
    pool2 = MaxPool1D(pool_size=2, strides=2, padding="same")(conv2_1)

    # Aplanar y capas densas
    flatten = Flatten()(pool2)
    dense_end1 = Dense(64, activation='relu')(flatten)
    dense_end2 = Dense(32, activation='relu')(dense_end1)
    main_output = Dense(4, activation='softmax', name='main_output')(dense_end2)

    # Compilar el modelo
    model = Model(inputs=inputs_cnn, outputs=main_output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Callbacks
    callbacks = [EarlyStopping(monitor='val_loss', patience=8),
                 ModelCheckpoint(filepath='best_model.h5', monitor='val_loss', save_best_only=True)]

    # Entrenamiento
    history = model.fit(X_train, y_train, epochs=33, callbacks=callbacks, batch_size=32, validation_data=(X_test, y_test))
    # model.load_weights('best_model_sinPreprocesado.h5')

    return model, history

# %%
def basic_network(X_train, y_train, X_test, y_test):
    input_shape = (X_train.shape[1],)

    inputs = Input(shape=input_shape, name='inputs')
    dense_layer1 = Dense(64, activation='relu')(inputs)
    dense_layer2 = Dense(32, activation='relu')(dense_layer1)
    main_output = Dense(4, activation='softmax', name='main_output')(dense_layer2)

    model = Model(inputs=inputs, outputs=main_output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    callbacks = [EarlyStopping(monitor='val_loss', patience=10),
                 ModelCheckpoint(filepath='best_basic_model.h5', monitor='val_loss', save_best_only=True)]

    history = model.fit(X_train, y_train, epochs=33, callbacks=callbacks, batch_size=32, validation_data=(X_test, y_test))

    return model, history

# %%
model, history = basic_network(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/33
# 225/225 [==============================] - 2s 3ms/step - loss: 1.0572 - accuracy: 0.5781 - val_loss: 1.3311 - val_accuracy: 0.3813
# Epoch 2/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.8627 - accuracy: 0.6601 - val_loss: 1.3719 - val_accuracy: 0.3997
# Epoch 3/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.7971 - accuracy: 0.6853 - val_loss: 1.4288 - val_accuracy: 0.4088
# Epoch 4/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.7455 - accuracy: 0.7092 - val_loss: 1.2606 - val_accuracy: 0.4475
# Epoch 5/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.7039 - accuracy: 0.7247 - val_loss: 1.2307 - val_accuracy: 0.4825
# Epoch 6/33
# 225/225 [==============================] - 1s 3ms/step - loss: 0.6749 - accuracy: 0.7408 - val_loss: 1.2644 - val_accuracy: 0.4671
# Epoch 7/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.6497 - accuracy: 0.7526 - val_loss: 1.0519 - val_accuracy: 0.5558
# Epoch 8/33
# 225/225 [==============================] - 1s 4ms/step - loss: 0.6295 - accuracy: 0.7613 - val_loss: 1.0192 - val_accuracy: 0.5720
# Epoch 9/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.6149 - accuracy: 0.7683 - val_loss: 1.0558 - val_accuracy: 0.5591
# Epoch 10/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.6023 - accuracy: 0.7706 - val_loss: 1.2528 - val_accuracy: 0.5004
# Epoch 11/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5882 - accuracy: 0.7807 - val_loss: 0.9282 - val_accuracy: 0.6157
# Epoch 12/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5795 - accuracy: 0.7822 - val_loss: 1.0019 - val_accuracy: 0.5866
# Epoch 13/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5684 - accuracy: 0.7903 - val_loss: 0.9782 - val_accuracy: 0.6028
# Epoch 14/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5585 - accuracy: 0.7933 - val_loss: 1.0227 - val_accuracy: 0.6007
# Epoch 15/33
# 225/225 [==============================] - 1s 3ms/step - loss: 0.5498 - accuracy: 0.7946 - val_loss: 0.8911 - val_accuracy: 0.6420
# Epoch 16/33
# 225/225 [==============================] - 1s 4ms/step - loss: 0.5441 - accuracy: 0.7996 - val_loss: 0.9327 - val_accuracy: 0.6157
# Epoch 17/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5400 - accuracy: 0.8006 - val_loss: 1.1094 - val_accuracy: 0.5699
# Epoch 18/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5314 - accuracy: 0.8039 - val_loss: 0.8407 - val_accuracy: 0.6728
# Epoch 19/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5290 - accuracy: 0.8019 - val_loss: 0.8556 - val_accuracy: 0.6753
# Epoch 20/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5218 - accuracy: 0.8050 - val_loss: 0.9219 - val_accuracy: 0.6445
# Epoch 21/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5145 - accuracy: 0.8110 - val_loss: 0.9126 - val_accuracy: 0.6499
# Epoch 22/33
# 225/225 [==============================] - 1s 4ms/step - loss: 0.5094 - accuracy: 0.8119 - val_loss: 0.8929 - val_accuracy: 0.6586
# Epoch 23/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5051 - accuracy: 0.8142 - val_loss: 0.8935 - val_accuracy: 0.6545
# Epoch 24/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4998 - accuracy: 0.8150 - val_loss: 0.8067 - val_accuracy: 0.6944
# Epoch 25/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4957 - accuracy: 0.8156 - val_loss: 0.8075 - val_accuracy: 0.6903
# Epoch 26/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4928 - accuracy: 0.8165 - val_loss: 0.9094 - val_accuracy: 0.6557
# Epoch 27/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4863 - accuracy: 0.8211 - val_loss: 0.8196 - val_accuracy: 0.6940
# Epoch 28/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4817 - accuracy: 0.8246 - val_loss: 0.8280 - val_accuracy: 0.6878
# Epoch 29/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4801 - accuracy: 0.8200 - val_loss: 0.8786 - val_accuracy: 0.6724
# Epoch 30/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4735 - accuracy: 0.8285 - val_loss: 0.9442 - val_accuracy: 0.6470
# Epoch 31/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4723 - accuracy: 0.8276 - val_loss: 0.7838 - val_accuracy: 0.7111
# Epoch 32/33
# 225/225 [==============================] - 1s 3ms/step - loss: 0.4695 - accuracy: 0.8274 - val_loss: 0.8369 - val_accuracy: 0.6948
# Epoch 33/33
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4621 - accuracy: 0.8282 - val_loss: 0.7793 - val_accuracy: 0.7202

# %%
def evaluate_model(history,X_test,y_test,model):
    scores = model.evaluate((X_test),y_test, verbose=0)
    print("Accuracy: %.2f%%" % (scores[1]*100))
    
    print(history)
    fig1, ax_acc = plt.subplots()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Model - Accuracy')
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()
    
    fig2, ax_loss = plt.subplots()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Model- Loss')
    plt.legend(['Training', 'Validation'], loc='upper right')
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.show()
    target_names=['0','1','2','3','4']
    
    y_true=[]
    for element in y_test:
        y_true.append(np.argmax(element))
    prediction_proba=model.predict(X_test)
    prediction=np.argmax(prediction_proba,axis=1)
    cnf_matrix = confusion_matrix(y_true, prediction)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cnf_matrix, annot=True, fmt='g', cmap='Blues')
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.title('Confusion Matrix')
    plt.show()

# %%
model,history=network(X_train,y_train,X_test,y_test)
# Out:
# Epoch 1/40
# 3125/3125 [==============================] - 39s 12ms/step - loss: 0.9068 - accuracy: 0.6525 - val_loss: 0.9929 - val_accuracy: 0.6080
# Epoch 2/40
# 3125/3125 [==============================] - 36s 11ms/step - loss: 0.8025 - accuracy: 0.6938 - val_loss: 1.0598 - val_accuracy: 0.5255
# Epoch 3/40
# 3125/3125 [==============================] - 35s 11ms/step - loss: 0.7662 - accuracy: 0.7089 - val_loss: 1.0644 - val_accuracy: 0.5336
# Epoch 4/40
# 3125/3125 [==============================] - 35s 11ms/step - loss: 0.7298 - accuracy: 0.7226 - val_loss: 0.7575 - val_accuracy: 0.7044
# Epoch 5/40
# 3125/3125 [==============================] - 35s 11ms/step - loss: 0.6901 - accuracy: 0.7379 - val_loss: 0.8414 - val_accuracy: 0.6568
# Epoch 6/40
# 3125/3125 [==============================] - 34s 11ms/step - loss: 0.6467 - accuracy: 0.7575 - val_loss: 0.7908 - val_accuracy: 0.6867
# Epoch 7/40
# 3125/3125 [==============================] - 34s 11ms/step - loss: 0.6020 - accuracy: 0.7729 - val_loss: 0.9053 - val_accuracy: 0.6536
# Epoch 8/40
# 3125/3125 [==============================] - 34s 11ms/step - loss: 0.5577 - accuracy: 0.7920 - val_loss: 0.7124 - val_accuracy: 0.7484
# Epoch 9/40
# 3125/3125 [==============================] - 37s 12ms/step - loss: 0.5168 - accuracy: 0.8074 - val_loss: 0.8745 - val_accuracy: 0.6804
# Epoch 10/40
# 3125/3125 [==============================] - 37s 12ms/step - loss: 0.4771 - accuracy: 0.8227 - val_loss: 0.9267 - val_accuracy: 0.7143
# Epoch 11/40
# 3125/3125 [==============================] - 36s 12ms/step - loss: 0.4432 - accuracy: 0.8358 - val_loss: 1.1341 - val_accuracy: 0.6656
# Epoch 12/40
# 3125/3125 [==============================] - 36s 12ms/step - loss: 0.4112 - accuracy: 0.8463 - val_loss: 1.2187 - val_accuracy: 0.6660
# Epoch 13/40
# 3125/3125 [==============================] - 36s 12ms/step - loss: 0.3822 - accuracy: 0.8590 - val_loss: 1.4240 - val_accuracy: 0.6374
# Epoch 14/40
# 3125/3125 [==============================] - 36s 12ms/step - loss: 0.3591 - accuracy: 0.8664 - val_loss: 1.3821 - val_accuracy: 0.6554
# Epoch 15/40
# 3125/3125 [==============================] - 37s 12ms/step - loss: 0.3348 - accuracy: 0.8773 - val_loss: 1.3799 - val_accuracy: 0.6686
# Epoch 16/40
# 3125/3125 [==============================] - 37s 12ms/step - loss: 0.3151 - accuracy: 0.8843 - val_loss: 1.5927 - val_accuracy: 0.6660

# %%
evaluate_model(history,X_test,y_test,model)
y_pred=model.predict(X_test)
# Out:
# Accuracy: 66.60%
# <keras.callbacks.History object at 0x00000224127619F0>
# 685/685 [==============================] - 3s 5ms/step
# 685/685 [==============================] - 3s 4ms/step

# %%
import pywt
def apply_wavelet_transform(signal, wavelet='db4', level=4):
    coeffs = pywt.wavedec(signal, wavelet, level=level)
    # Aplanar los coeficientes para obtener un único vector de características
    flattened_coeffs = np.hstack([coeff.flatten() for coeff in coeffs])
    return flattened_coeffs

def preprocess_data_with_wavelets(X):
    # Aplica la transformación wavelet a cada muestra en X
    return np.array([apply_wavelet_transform(signal) for signal in X])

X_train_wavelet = preprocess_data_with_wavelets(X_train)
X_test_wavelet = preprocess_data_with_wavelets(X_test)

# Redimensionar para la red neuronal
X_train_wavelet = X_train_wavelet.reshape(X_train_wavelet.shape[0], X_train_wavelet.shape[1], 1)
X_test_wavelet = X_test_wavelet.reshape(X_test_wavelet.shape[0], X_test_wavelet.shape[1], 1)

# %%
model, history = network(X_train_wavelet, y_train, X_test_wavelet, y_test)
# Out:
# Epoch 1/40
# 3125/3125 [==============================] - 1819s 581ms/step - loss: 1.0937 - accuracy: 0.5735 - val_loss: 5.7308 - val_accuracy: 0.1154
# Epoch 2/40
# 3125/3125 [==============================] - 1831s 586ms/step - loss: 0.9705 - accuracy: 0.6241 - val_loss: 2.5955 - val_accuracy: 0.1405
# Epoch 3/40
# 3125/3125 [==============================] - 3042s 974ms/step - loss: 0.9343 - accuracy: 0.6407 - val_loss: 1.2337 - val_accuracy: 0.4658
# Epoch 4/40
# 3125/3125 [==============================] - 2689s 860ms/step - loss: 0.9044 - accuracy: 0.6515 - val_loss: 1.1997 - val_accuracy: 0.4950
# Epoch 5/40
# 3125/3125 [==============================] - 1826s 584ms/step - loss: 0.8722 - accuracy: 0.6663 - val_loss: 1.5172 - val_accuracy: 0.2180
# Epoch 6/40
# 3125/3125 [==============================] - 1554s 497ms/step - loss: 0.8488 - accuracy: 0.6771 - val_loss: 1.6509 - val_accuracy: 0.2515
# Epoch 7/40
# 3125/3125 [==============================] - 1574s 504ms/step - loss: 0.8234 - accuracy: 0.6889 - val_loss: 1.5246 - val_accuracy: 0.2656
# Epoch 8/40
# 3125/3125 [==============================] - 1556s 498ms/step - loss: 0.7998 - accuracy: 0.6991 - val_loss: 2.3257 - val_accuracy: 0.2255
# Epoch 9/40
# 3125/3125 [==============================] - ETA: 0s - loss: 0.7767 - accuracy: 0.7082

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(10, 10))
plot_confusion_matrix(cnf_matrix, classes=['N', 'S', 'V', 'F', 'Q'],normalize=True,
                      title='Confusion matrix, with normalization')
plt.show()
# Out:
# Normalized confusion matrix
